# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
trollTweets = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\RussianTrolltweets\IRAhandle_tweets_1.csv")

# %%
trollTweets.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates  ...  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253  ...
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254  ...
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255  ...
# ...

# %%
MAGATweers = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\wendyhe-tweets-on-womensmarch-and-maga\wendyhe-tweets-on-womensmarch-and-maga\MAGAtweets.csv")

# %%
MAGATweers.head()
# Out:
#                    id                                               text  \
# 0  822594553169514497  Photo right: crowded Wash. Mall 2009 vs Left: ...
# 1  822594551718281219  Beautiful family @realDonaldTrump   Let's #MAG...
# 2  822594549797240835                    #MAGA 😶 https://t.co/dfVr03ip4d
# 3  822594549738569729              #Patriot - - - - &gt; @GopAaron #MAGA
# 4  822594547968516096  Won't read it. You're a con man. You are disgu...
#
#                 source           created_at  Unnamed: 4
# 0   Twitter Web Client  2017-01-20 23:59:59         NaN
# 1   Twitter Web Client  2017-01-20 23:59:58         NaN
# 2  Twitter for Android  2017-01-20 23:59:58         NaN
# 3      Mobile Web (M5)  2017-01-20 23:59:58         NaN
# 4  Twitter for Android  2017-01-20 23:59:57         NaN

# %%
MarchTweets = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\wendyhe-tweets-on-womensmarch-and-maga\wendyhe-tweets-on-womensmarch-and-maga\womensmarchtweets.csv")

# %%
MarchTweets.head()
# Out:
#                    id                                               text  \
# 0  822956943849517057  #WomensMarch Can someone send me a pussy-hat ?...
# 1  822956943501328385  🌸o melhor protesto da história que voce admira...
# 2  822956943429902338  I thank God that we have each other! #WomensMa...
# 3  822956943388065792               #WomensMarch https://t.co/otODcBgLUO
# 4  822956942746353664  39) "la agenda gay" louder and proud #WomensMa...
#
#                 source           created_at  Unnamed: 4
# 0   Twitter for iPhone  2017-01-21 23:59:59         NaN
# 1   Twitter for iPhone  2017-01-21 23:59:59         NaN
# 2   Twitter for iPhone  2017-01-21 23:59:59         NaN
# 3   Twitter for iPhone  2017-01-21 23:59:59         NaN
# 4  Twitter for Android  2017-01-21 23:59:59         NaN

# %%
combinedTweets = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\EECS731_combined_v1.csv")

# %%
combinedTweets.head()
# Out:
#   Source    twitter_id                                               text  \
# 0   MAGA  8.225946e+17  Photo right: crowded Wash. Mall 2009 vs Left: ...
# 1   MAGA  8.225946e+17  Beautiful family @realDonaldTrump   Let's #MAG...
# 2   MAGA  8.225945e+17                    #MAGA 😶 https://t.co/dfVr03ip4d
# 3   MAGA  8.225945e+17              #Patriot - - - - &gt; @GopAaron #MAGA
# 4   MAGA  8.225945e+17  Won't read it. You're a con man. You are disgu...
#
#   language
# 0       en
# 1       en
# 2       hu
# 3       te
# 4       en

# %%
combinedTweets.plot()
